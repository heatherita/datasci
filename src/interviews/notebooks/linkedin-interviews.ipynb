# %%
from interviews.db.database import SessionLocal, engine
from interviews.service.linkedin_service import add_contact, get_contact_by_fullname
from interviews.client.li_interview import script_interview
from sqlalchemy import inspect

import pandas as pd

db = SessionLocal()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 2
#       1 from interviews.db.database import SessionLocal, engine
# ----> 2 from interviews.service.linkedin_service import add_contact, get_contact_by_fullname
#       3 from interviews.client.li_interview import script_interview
#       4 from sqlalchemy import inspect
#
# ImportError: cannot import name 'get_contact_by_fullname' from 'interviews.service.linkedin_service' (/home/heather/dev/PycharmProjects/datasci/src/interviews/service/linkedin_service.py)

# %%
df = pd.read_sql("select * from li.interview", db.bind)
df.head()

# %%
inspector = inspect(engine)

# list schemas
# print(inspector.get_schema_names())

# list tables in your "li" schema
print(inspector.get_table_names(schema="li"))

# %%
# contact = add_contact("mary","project manager","Miele")
contact = get_contact_by_fullname("mary",
delete_contact(2)

# %%
df = pd.read_sql("select * from li.contact", db.bind)
df.head()

# %%
script_interview()

# %%
df = pd.read_sql("select * from li.interview_qa", db.bind)
df.head()
